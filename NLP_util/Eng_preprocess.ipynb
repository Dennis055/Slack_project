# %%
#讀入我們會用到的套件
import pandas as pd
import datetime
import jieba
from datetime import datetime
import plotly.graph_objs as go
import plotly.offline as py
py.init_notebook_mode(connected=True) #為了能在本地端調用
import plotly.tools as tls
import plotly.figure_factory as ff
from wordcloud import WordCloud
from collections import Counter
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import swifter
import numpy as np
import itertools
from scipy.sparse import csr_matrix
# libraries
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
# path = '/Users/Dennis/Downloads/community_team_meeting.xlsx'
path = '/Users/Dennis/Downloads/forums.xlsx'

df = pd.read_excel(path)
df = df.head(1000)
df.head(3)
# Out:
#    Unnamed: 0        user_name                      text_time  \
# 0         1.0      **anevins**  6:42 AM, September 30th, 2018
# 1         2.0      **anevins**  6:42 AM, September 30th, 2018
# 2         3.0  **tokyobiyori**  6:47 AM, September 30th, 2018
#
#                                                 text
# 0                                    On another note
# 1  When you help users and they say "maybe someon...
# 2                                                lol

# %%
import pandas as pd # our main data management package
import matplotlib.pyplot as plt # our main display package
import string # used for preprocessing
import re # used for preprocessing
import nltk # the Natural Language Toolkit, used for preprocessing
import numpy as np # used for managing NaNs
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords # used for preprocessing
from nltk.stem import WordNetLemmatizer # used for preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression # our model
from sklearn.model_selection import train_test_split



def remove_urls(text):
    new_text = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",text).split())
    return new_text

# make all text lowercase
def text_lowercase(text):
    return text.lower()
# remove numbers
def remove_numbers(text):
    result = re.sub(r'\d+', '', text)
    return result
# remove punctuation
def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)
# tokenize
def tokenize(text):
    text = word_tokenize(text)
    return text


# remove stopwords defined in NLTK
def remove_stopwords(text , stop_words):
    text = [i for i in text if not i in stop_words]
    return text


def lemmatize(text ,lemmatizer):
    text = [lemmatizer.lemmatize(token) for token in text]
    return text

class NLP_Eng_Processor:
    
    def __init__(self ,  df ):
        """
        df(DataFrame) : Raw data in text data frame format
        
        """
        self.df = df.copy()
        self.original_text = df['text'].copy()
         # remove stopwords
        self.stop_words = set(stopwords.words('english'))
         # lemmatize
        self.lemmatizer = WordNetLemmatizer()
    
   

    def preprocessing(self , text):
        text = text_lowercase(text)
        text = remove_urls(text)
        text = remove_numbers(text)
        text = remove_punctuation(text)
        text = tokenize(text)
        text = remove_stopwords(text , self.stop_words)
        text = lemmatize(text , self.lemmatizer)
        text = ' '.join(text)
        return text 
    
    def run_preprocess_script(self):
        """
        Exe the script to preprocess dataframe text 
        """
        all_text = self.df['text']
        clean_text  = []
        for text in all_text:
            clean_text.append(self.preprocessing(text))
            
        # add the preprocessed text as a column
        self.df['text'] = clean_text
        temp_df = pd.DataFrame([ pd.Series(clean_text) , self.original_text]).T
        temp_df.columns = ['clean_text' , 'original_text']
        return temp_df

# %%
preprocess_assistant = NLP_Eng_Processor(df)
# preprocess_assistant.original_text
preprocess_assistant.run_preprocess_script()
# Out:
#                                             clean_text  \
# 0                                         another note
# 1    help user say maybe someone else help instead ...
# 2                                                  lol
# 3                                           giant sigh
# 4                                     may british word
# 5    hi amazing script avoid overlapping reply foru...
# 6                           hi p thank script make use
# 7                                         need blocked
# 8                                                order
# 9       possibly need looking fall review category imo
# 10        meh review gutenberg review trying sensitive
# 11                                   good jan pet head
# 12                                       ha shake fist
# 13                                       early morning
# 14   please report review unless abuse third one re...
# 15                   aaaand replied wrong place edited
# 16                   anyone know slack invitation sent
# 17   finally solved child theme issue modify global...
# 18   tell email slackinvitehelp org go password res...
# 19           need username email address info relevant
# 20   change support theme need meta ticket would re...
# 21   think ticket right way go esp could suggest be...
# 22   wp life please repost reply topic plugin autho...
# 23           topic need move health check plugin think
# 24   saw post confused health check nothing reverti...
# 25   well plugin theme editor us loopback check err...
# 26                       seems like plugin message end
# 27         saw review said customer service plugin bad
# 28                               multiple account good
# 29                                   wondered long see
# ..                                                 ...
# 970      fun making enjoy day infrastructure operation
# 971  let know find anything odd quick push update s...
# 972  may something sure bb polylang root possible e...
# 973                vague yet specific bugreport edited
# 974                        realised late shall try nap
# 975                                    plugins shudder
# 976                              yup static front page
# 977                                           polylang
# 978                     oh site another one remembered
# 979                     issue week back medium library
# 980                                              brent
# 981                             say beaver around look
# 982                                               well
# 983                                          brings aw
# 984                                            checkin
# 985                                             coolio
# 986                            ordered large starbucks
# 987                                                lol
# 988                                            exactly
# 989  go back old store order fiesta family fun pack...
# 990                                                idk
# 991                      support local coffeeshops lol
# 992                                time meeting client
# 993                                             really
# 994                                             really
# 995                                           look one
# 996  trying engage whole conversation already derailed
# 997                                                mmm
# 998                                          soonsteak
# 999                                        much thanks
#
#                                          original_text
# 0                                      On another note
# 1    When you help users and they say "maybe someon...
# 2                                                  lol
# 3                                         <GIANT SIGH>
# 4                           That may be a british word
# 5    Hi @Vignesh, here is an amazing script to Avoi...
# 6    Hi @t-p Thank you for the script. Will make us...
# 7    https://wordpress.org/support/users/yirolegmai...
# 8                                       In that order.
# 9    This possibly needs looking at, as this falls ...
# 10   Meh. Not a review but with Gutenberg reviews w...
# 11                                Good Jan pet on head
# 12                                     HA! SHAKES FIST
# 13                       It's too early in the morning
# 14   @wooninjas Once again, please do not report re...
# 15      Aaaand I replied in the wrong place. (edited)
# 16   anyone know how to have a slack invitation re-...
# 17   I finally solved my 2017 child theme issues --...
# 18   @sterndata tell them to email slackinvitehelp@...
# 19   Need username, email address, other info as re...
# 20   Does a change to the Support theme need a meta...
# 21   I think a ticket is the right way to go, esp. ...
# 22   @A WP Life Please repost your reply on this to...
# 23   This topic needs to move to Health Check plugi...
# 24   I saw that post and it confused me.  Health Ch...
# 25   Well, if you are in the plugin or theme editor...
# 26   But it seems like it's the plugin because of t...
# 27   I saw a review that said the customer service ...
# 28                 Multiple accounts. That's not good.
# 29            wondered how long before you'd see that.
# ..                                                 ...
# 970  I had fun making it all, it's what i enjoy the...
# 971  Let me know if you find anything odd. Were qui...
# 972  I may have something, but I'm not sure if it's...
# 973         Vague, yet specific, bugreport\n (edited)
# 974  And now i realised how late it is, so I shall ...
# 975                               i18n plugins shudder
# 976              Yup, but only for static front pages!
# 977                                 Polylang.... :why:
# 978  oh, that's not on my site, that's on another o...
# 979  I had an issue a few weeks back with the media...
# 980                                           BRENT!!!
# 981       You say “beaver” around here and we all look
# 982                                           Well now
# 983                       What brings you about he-aw?
# 984                                    Just checkin in
# 985                                             Coolio
# 986                     I ordered a large at Starbucks
# 987                                              :lol:
# 988                                            Exactly
# 989  I only go back to my old store to order the Fi...
# 990                                   Idk what that is
# 991                    I support local coffeeshops lol
# 992          Just not this time, meeting with a client
# 993                                            Really?
# 994                                            Really.
# 995  @Otto Can you look at this one? https://wordpr...
# 996  I’m trying not to engage as the whole conversa...
# 997                                              mmm..
# 998                                        :soonsteak:
# 999                                       Much thanks.
#
# [1000 rows x 2 columns]
