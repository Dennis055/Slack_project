# %%
import pandas as pd # our main data management package
import matplotlib.pyplot as plt # our main display package
import string # used for preprocessing
import re # used for preprocessing
import nltk # the Natural Language Toolkit, used for preprocessing
import numpy as np # used for managing NaNs
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords # used for preprocessing
from nltk.stem import WordNetLemmatizer # used for preprocessing
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression # our model
from sklearn.model_selection import train_test_split


# path = '/Users/Dennis/Downloads/community_team_meeting.xlsx'
path = '/Users/Dennis/Downloads/forums.xlsx'

df = pd.read_excel(path)
# df = df.head(1000)
df.head(3)
# Out:
#    Unnamed: 0        user_name                      text_time  \
# 0         1.0      **anevins**  6:42 AM, September 30th, 2018
# 1         2.0      **anevins**  6:42 AM, September 30th, 2018
# 2         3.0  **tokyobiyori**  6:47 AM, September 30th, 2018
#
#                                                 text
# 0                                    On another note
# 1  When you help users and they say "maybe someon...
# 2                                                lol

# %%
from EN_preprocess import *
from EN_util import NLP_Eng_Assistant


# stopwords = 


processor_assistant = NLP_Eng_Processor(df)
processor_assistant.run_preprocess_script(False)
# df['text'] = df['text'].apply(lambda x: remove_urls(x))
# df['text'] = df['text'].apply(lambda x:remove_punctuation(x))
# df['text'] = df['text'].apply(lambda x:remove_stopwordso(x))
# df['text'] = df['text'].apply(lambda x:remove_numbers(x))
pipe_df = processor_assistant.df
# pipe_df = pr
print('-' *20)
"""
test
"""        

tool = NLP_Eng_Assistant(pipe_df, 'text' , stopwords)
tool.run_nlp_analysis_script()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# /Users/Dennis/anaconda3/lib/python3.7/site-packages/yaml/constructor.py:126: DeprecationWarning:
#
# Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#
# /Users/Dennis/anaconda3/lib/python3.7/site-packages/networkx/classes/reportviews.py:95: DeprecationWarning:
#
# Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
# --------------------
#  Stopwords are the words that are most commonly used in any language such as “the”,” a”,” an” etc. As these words are probably small in length these words may have caused the above graph to be left-skewed.
# /Users/Dennis/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3335: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/Dennis/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning:
#
# invalid value encountered in double_scalars
# show top ngram failed...
# show_top_stopwords_bar_plot failed...
# Start LDA modeling...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-d9730d46ebda> in <module>
#      20
#      21 tool = NLP_Eng_Assistant(pipe_df, 'text' , stopwords)
# ---> 22 tool.run_nlp_analysis_script()
#
# ~/data_science/slack_project/R&D/NLP_util/EN_util.py in run_nlp_analysis_script(self)
#     463         self.show_wordcloud()
#     464
# --> 465         self.ml_lda_script(4)
#     466         self.ml_NER_in_most_common()
#     467
#
# ~/data_science/slack_project/R&D/NLP_util/EN_util.py in ml_lda_script(self, topic_num, show_lda_vis)
#     211         text = self.content
#     212         print('Start LDA modeling...')
# --> 213         lda_model, bow_corpus, dic = train_lda_objects(text , topic_num , self.stopwords)
#     214         word_dict = {};
#     215         for i in range(topic_num):
#
# ~/data_science/slack_project/R&D/NLP_util/EN_util.py in train_lda_objects(text, topic_num, stop)
#      61         return corpus
#      62
# ---> 63     corpus=_preprocess_text(text)
#      64
#      65     dic=gensim.corpora.Dictionary(corpus)
#
# ~/data_science/slack_project/R&D/NLP_util/EN_util.py in _preprocess_text(text)
#      56             words=[w for w in word_tokenize(news) if (w not in stop)]
#      57
# ---> 58             words=[lem.lemmatize(w) for w in words if len(w)>2]
#      59
#      60             corpus.append(words)
#
# ~/data_science/slack_project/R&D/NLP_util/EN_util.py in <listcomp>(.0)
#      56             words=[w for w in word_tokenize(news) if (w not in stop)]
#      57
# ---> 58             words=[lem.lemmatize(w) for w in words if len(w)>2]
#      59
#      60             corpus.append(words)
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/stem/wordnet.py in lemmatize(self, word, pos)
#      39
#      40     def lemmatize(self, word, pos=NOUN):
# ---> 41         lemmas = wordnet._morphy(word, pos)
#      42         return min(lemmas, key=len) if lemmas else word
#      43
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/corpus/reader/wordnet.py in _morphy(self, form, pos, check_exceptions)
#    1910
#    1911         # 1. Apply rules once to the input to get y1, y2, y3, etc.
# -> 1912         forms = apply_rules([form])
#    1913
#    1914         # 2. Return all that are in the database (and check the original too)
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/corpus/reader/wordnet.py in apply_rules(forms)
#    1888             return [
#    1889                 form[: -len(old)] + new
# -> 1890                 for form in forms
#    1891                 for old, new in substitutions
#    1892                 if form.endswith(old)
#
# ~/anaconda3/lib/python3.7/site-packages/nltk/corpus/reader/wordnet.py in <listcomp>(.0)
#    1890                 for form in forms
#    1891                 for old, new in substitutions
# -> 1892                 if form.endswith(old)
#    1893             ]
#    1894
#
# KeyboardInterrupt:
